# %% [markdown]
# # Covid-19 and Character Strengths Dataset (Regression)
#
#
#
#
# Louaye Mandari
#
#
#
# ## Introduction
# This project will be focusing on investigation of prolonged
# waves of COVID-19's psychological effects on people. Most of the work covers COVID19 related cases across the world and will be analyzed by required tools.
# In this project, we are going to work with the COVID-19 dataset, published by Open
# Research Dataset in kaggle from John Hopkins University. The data represents
# the cumulative number of confirmed cases, per day, in each Country. We will use the datasets in
# order to establish relationships between the psychological health of people during the pandemic
# of COVID19.
#
# ### Problem Definition
# The major problem of the project is to make the regression analysis of the data-sets and find out if there are any relations present between COVID-19 and psychological health of people or not.
#
# In addition we are currently facing a problem, which is to find another supporting and sufficient data-set, preferably well organized and error-free, that we could analyze to find trends and correlations.
#
# ### Utilized Datasets
# In this project,we may use some sets from multiple sources. To our advantage, Kagle.com offers a variety of COVID-19 related datasets. Data-sets, we are currently using some of the datasets below are given below:
#
# -COVID-19 Dataset, Number of Confirmed, Death and Recovered cases every day across the globe: https://www.kaggle.com/imdevskp/corona-virus-report
#
# -World Happiness Report 2021: https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021
#
# -World Happiness Report
# Happiness scored according to economic production, social support, etc.: https://www.kaggle.com/unsdsn/world-happiness
#
# -Novel CoronaVirus 2019 Dataset
# Day level information on covid-19 affected cases: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset
#
# -Covid-19 and Character Strengths
# Strengths, Psychological Distress and Self‑efficacy During Covid-19 Lockdown: https://www.kaggle.com/mathchi/covid19-and-character-strengths
#
# -Survey in 48 languages collecting global data on the psychological and behavioural impact of the COVID-19/coronavirus crisis. Collaborative open science project. By the COVIDiSTRESS global survey research community.
# https://osf.io/z39us/
#
# -World Happiness Report 2020
# Data used to calculate the Happiness Score for 153 countries
# https://www.kaggle.com/londeen/world-happiness-report-2020

# %% [markdown]
# ## Data Exploration
#
# <font color="white">
#
# In this part we will explore the data using data analysis tools that we learned in this course.
# </font>

# %% [markdown]
# ## Step 1)
# we will use a simple data cleaning method to check for any missing data before we start tinkering with the data further down the Line

# %%
# to disable warning outputs
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
import seaborn as sns
import tensorflow as tf
import sys
import warnings
import math
# %matplotlib inline
if not sys.warnoptions:
    warnings.simplefilter("ignore")

import json
def sigmoid(x):
  return 1 / (1 + math. exp(-x))
print(sigmoid(0.5))
# Out:
# 0.6224593312018546

# %%
from google.colab import drive
drive.mount("./drive")

path_prefix = "./drive/My Drive"
# Out:
# Drive already mounted at ./drive; to attempt to forcibly remount, call drive.mount("./drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
fname = "DBCOVID.csv"
d1 = pd.read_csv(join(path_prefix, fname))
d1.head(3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Participant  Openness  Restraint  ...  DASS_anxiety  DASS_depression  DASS_stress
# 0            1       102         51  ...             0                7            8
# 1            2        96         49  ...             4                5            9
# 2            3        99         58  ...             0                0            0
#
# [3 rows x 41 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
fname = "2020edit.csv"
d2 = pd.read_csv(join(path_prefix, fname))
d2.head(3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Country name  ... Dystopia + residual
# 0  Afghanistan  ...            1.507236
# 1      Albania  ...            1.640897
# 2      Algeria  ...            1.840812
#
# [3 rows x 20 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

fname = "COVIDiSTRESSMay30Cleaned.csv"
d3 = pd.read_csv(join(path_prefix, fname), encoding='latin-1')##error so we had to add the encoding latin 1

d3.head(15)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     ID answered_all  ...  SPS_avg Scale_UCLA_TRI_avg
# 0    1           No  ...      NaN                NaN
# 1    2           No  ...      5.0                NaN
# 2    3           No  ...      NaN                NaN
# 3    4           No  ...      3.9                NaN
# 4    5           No  ...      5.0                NaN
# 5    6          Yes  ...      5.0                NaN
# 6    7          Yes  ...      4.0                NaN
# 7    8          Yes  ...      5.4                NaN
# 8    9           No  ...      4.9                NaN
# 9   10           No  ...      NaN                NaN
# 10  11           No  ...      NaN                NaN
# 11  12          Yes  ...      4.9                NaN
# 12  13           No  ...      5.1                NaN
# 13  14          Yes  ...      5.0                NaN
# ...

# %% [markdown]
# After installing and mounting the files to our notebook,we then go through the process of cleaning the data

# %%
##droping Na values
d1.isna().sum()
# Out:
# Participant               0
# Openness                  0
# Restraint                 0
# Transcendence             0
# Interpersonal             0
# DASS_21                   0
# GHQ_12                    0
# SEC                       0
# Age                       0
# Gender                    0
# Work                      0
# Student                   1
# Day                       0
# Sons                      0
# Appreciation_of_beauty    0
# Bravery                   0
# Creativity                0
# Curiosity                 0
# Fairness                  0
# Forgiveness               0
# Gratitude                 0
# Honesty                   0
# Hope                      0
# Humilty                   0
# Humor                     0
# Judgment                  0
# Kindness                  0
# Leadership                0
# Love                      0
# Love_of_learning          0
# Perseverance              0
# Perspective               0
# Prudence                  0
# ...

# %%
d2.isna().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
d3.isna().sum()
# Out:
# ID                            0
# answered_all                  0
# Duration..in.seconds.         0
# UserLanguage                  0
# Dem_age                       0
#                           ...
# ope                       16987
# agr                       16976
# con                       16984
# SPS_avg                   30917
# Scale_UCLA_TRI_avg       125255
# Length: 153, dtype: int64

# %% [markdown]
# after finding the number of columns that has the highest number of NA values we can quickly swoop in with a delation tool that can delete all these values frim our dataframes.

# %%
d1 = d1.dropna()
d1.isna().sum()
# Out:
# Participant               0
# Openness                  0
# Restraint                 0
# Transcendence             0
# Interpersonal             0
# DASS_21                   0
# GHQ_12                    0
# SEC                       0
# Age                       0
# Gender                    0
# Work                      0
# Student                   0
# Day                       0
# Sons                      0
# Appreciation_of_beauty    0
# Bravery                   0
# Creativity                0
# Curiosity                 0
# Fairness                  0
# Forgiveness               0
# Gratitude                 0
# Honesty                   0
# Hope                      0
# Humilty                   0
# Humor                     0
# Judgment                  0
# Kindness                  0
# Leadership                0
# Love                      0
# Love_of_learning          0
# Perseverance              0
# Perspective               0
# Prudence                  0
# ...

# %%
d2 = d2.dropna()
d2.isna().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %% [markdown]
# Since all the Data in D3 dataFrame on all rows have at least a single NA cell
# we came to the conclusion that we will utilize only the columns that we need instead of using the previous method to view th data.
#
# So our plan here is to take the usful columns and take there mean and add them back into a concise and useful dataframe.

# %%
d3stress = d3[["Scale_PSS10_UCLA_1", "Scale_PSS10_UCLA_2","Scale_PSS10_UCLA_3","Scale_PSS10_UCLA_4","Scale_PSS10_UCLA_5","Scale_PSS10_UCLA_6",
               "Scale_PSS10_UCLA_7","Scale_PSS10_UCLA_8","Scale_PSS10_UCLA_9","Scale_PSS10_UCLA_10"]]
               #after getting the new data frame of stress values
d3stress = d3stress.dropna()
d3stress['average of stress'] = d3stress.mean(axis=1)
d3stress
d3stressg = d3stress.drop(d3stress.index[range(112035)])
d3stressg
#############################################
d3c = d3[["Corona_concerns_1", "Corona_concerns_2","Corona_concerns_3","Corona_concerns_4",
            "Corona_concerns_5"]]

d3c = d3c.dropna()

d3c['Average covid19 concern'] = d3c.mean(axis=1)
k= int(sum(d3c['Average covid19 concern'])) - 200
d3cg = d3c.drop(d3c.index[range(108277)])

d3cg 
#############################################

d3ntp = d3[["OECD_people_1", "OECD_people_2"]]

d3ntp = d3ntp.dropna()

d3ntp['Average trust in people'] = d3ntp.mean(axis=1)
d3ntpg = d3ntp.drop(d3ntp.index[range(110655)])
d3ntpg
##############################################

d3in = d3[["OECD_insititutions_1", "OECD_insititutions_2",'OECD_insititutions_3',
           'OECD_insititutions_4','OECD_insititutions_5']]

d3in = d3in.dropna()

d3in['Average trust in the health system'] = d3in.mean(axis=1)

d3ing = d3in.drop(d3in.index[range(105999)])
d3ing
#we are aiming at lower rows to make it easier for graphs
# Out:
#         OECD_insititutions_1  ...  Average trust in the health system
# 125004                   3.0  ...                                 5.0
# 125005                   8.0  ...                                 8.4
# 125006                   9.0  ...                                 7.8
# 125007                   9.0  ...                                 9.8
# 125008                   7.0  ...                                 8.0
# ...                      ...  ...                                 ...
# 125299                   6.0  ...                                 7.6
# 125300                   9.0  ...                                 9.4
# 125301                   7.0  ...                                 7.6
# 125302                   8.0  ...                                 8.6
# 125304                   7.0  ...                                 7.0
#
# [250 rows x 6 columns]

# %% [markdown]
# ## Step 2)
#
#
#
# In this step after getting rid of any supposed empty cells, we start by viewing the data in a visual manner using matplotlib library of python.This library will allow us to harness functions that can visually draw the given relations graphicly.

# %%
d1s =[d1['Interpersonal'],d1['Teamwork'],d1['Forgiveness'],d1['DASS_depression'],d1['Age']]

headers = ['Interpersonal','Teamwork','Forgiveness','DASS_depression',
          'Age']

data = pd.concat(d1s, axis=1, keys=headers)

sns.pairplot(data[['Interpersonal', 'Teamwork','Forgiveness','DASS_depression','Age']], diag_kind='kde')

# %%
d2s =[d2['Logged GDP per capita'],d2['Ladder score'],d2['Healthy life expectancy'],d2['Social support']]

headers = ['Logged GDP per capita','happyness score','Healthy life expectancy','Social support']

data = pd.concat(d2s, axis=1, keys=headers)

sns.pairplot(data[['Logged GDP per capita', 'happyness score','Healthy life expectancy','Social support']], diag_kind='kde')

# %% [markdown]
# In this part we will use the seaborn library to establish a usful form of visualization using 16 diffrent graphs combining the 4 diffrent matrices.

# %%
#obs2 from second Data set
d3s =[d3ntpg['Average trust in people'],d3stressg['average of stress'],d3ing['Average trust in the health system'],d3cg['Average covid19 concern']]

headers = ['Average trust in people','average of stress','Average trust in the health system','Average covid19 concern']

data = pd.concat(d3s, axis=1, keys=headers)

sns.pairplot(data[['Average trust in people', 'average of stress','Average trust in the health system','Average covid19 concern']], diag_kind='kde')

# %% [markdown]
# ## Step 3)
# After finding the potential points that we would like to discover.
# We will set up the following assumptions in a hypothesis tests.Hypothesis tests are a statistical tools used to determine the validity of an argument or a claim by f=giving the preserved claim and its contrary alternative.After setting them,we use other statistical tools of significance to determine there statistical significance .

# %% [markdown]
# ### First hypothesis
# In this hypothesis,we have the assumption that more most people will score more than or equal to 4 in there stress test (stress tests are out of 5) during this covid 19 pandeimic.So we set the following hypothesis:
#
# H0:the majority of people will score 4 or more on the stress test
#
# H1:the majority of people will NOT score 4 or more on the stress test

# %%
# Calculating p-value
# p_value = len(veg_rates[veg_rates >= 0.16]) / len(veg_rates) ##total number of values more than x over total values
# print("p-value: ", p_value) ##
p_value = sum(d3stress['average of stress'] >= 4) / sum(d3stress['average of stress'] >= 0)
print("p-value: ", p_value)
# Out:
# p-value:  0.009814311795876563

# %% [markdown]
# After getting our p value, we move on to test the hypothesis test with an alpha= 0.05 and we then set out a loop as follows:

# %%
alpha = 0.05

if p_value <= alpha:
  print("We reject Null Hypothesis")
  print("the majority of people will not score 4 or more on the stress test")
else:
   print("We fail to reject Null Hypothesis!")
   print("The majority of people will score 4 or more on the stress test")
# Out:
# We reject Null Hypothesis
# the majority of people will not score 4 or more on the stress test

# %% [markdown]
# ### Second hypothesis
# In this hypothesis,we have the assumption that more most people will score more than or equal to 7 in their belief in there health system test (tests are out of 10) during this covid 19 pandeimic.So we set the following hypothesis:
#
# H0:the majority of people will score 7 or more on the belief in there health system test
#
# H1:the majority of people will NOT score 7 or more on the belief in there health system test

# %%
p_value = sum(d3in['Average trust in the health system'] >= 7) / sum(d3in['Average trust in the health system'] >= 0)
print("p-value: ", p_value)
# Out:
# p-value:  0.40928385208331375

# %% [markdown]
# After getting our p value, we move on to test the hypothesis test with an alpha= 0.05 and we then set out a loop as follows

# %%
alpha = 0.05

if p_value <= alpha:
  print("We reject Null Hypothesis")
  print("the majority of people will NOT score 7 or more on the belief in there health system test")
else:
  print("We fail to reject Null Hypothesis!")
  print("the majority of people will score 7 or more on the belief in there health system test")
# Out:
# We fail to reject Null Hypothesis!
# the majority of people will score 7 or more on the belief in there health system test

# %% [markdown]
# ### Third hypothesis
# In this hypothesis,we have the assumption that most people will score more than or equal to 7 in their belief in their Trust in People test (tests are out of 10) during this covid 19 pandemic. So we set the following hypothesis:
#
# H0:the majority of people will score 8 or more on their Trust in people test
#
# H1:the majority of people will NOT score 8 or more on their Trust in people test

# %%
p_value = sum(d3ntp['Average trust in people'] >= 8) / sum(d3ntp['Average trust in people'] >= 0)
print("p-value: ", p_value)
# Out:
# p-value:  0.3143320860195663

# %% [markdown]
# After getting our p value, we move on to test the hypothesis test with an alpha= 0.05 and we then set out a loop as follows

# %%
alpha = 0.05

if p_value <= alpha:
  print("We reject Null Hypothesis")
  print("the majority of people will NOT score 8 or more on there Trust in people test")
else:
  print("We fail to reject Null Hypothesis!")
  print("the majority of people will score 8 or more on there Trust in people test")
# Out:
# We fail to reject Null Hypothesis!
# the majority of people will score 8 or more on there Trust in people test

# %% [markdown]
# ## Machine Learning Models
#
# In this section,we will use machine learning techniques in order to help us build models that describe and fit the given data sets.
# In the beginning we will set The datasets according to the regression technique to predict the future values from the models.
#
# The Advantages  of Implementing a Machine Learning in our project:
#
# -It identifies trends and patterns very easily.
#
# -It improves itself over time.
#
# -It is self-sufficient and assorted.
#
# -Saves time and is energy-efficient.

# %% [markdown]
# ##step 1)
# we will use statitical regression.
# this tool is about using linear relation ships between two sets of data to predict a set of futuritic data. Or in a more technical language, Linear regression performs the task to predict a **dependent variable** value `y` based on given **independent variable(s)** `x`. The relationship between `y` and `x` is represented by a linear equation.
#
# $y \, = \, m_1*x_1 \, + ... + \, m_n*x_n \, + \, b$
#
# ![](https://faculty.elgin.edu/dkernler/statistics/ch04/images/slope-intercept.gif)

# %% [markdown]
# We will start off by importing some important libraries

# %%
from ipywidgets import interact
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ###Plot A
# in this part, we use regression for social support and happyness scores

# %%
x = d2['Social support']
y = d2['Ladder score']

x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.xlabel('Social support')
plt.ylabel('happyness score')
plt.show()
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)
# Out:
# The mean Squared for the above graph is  1.4333929706017927

# %% [markdown]
# ### Plot A
# in this plot it seems our regression may be improved if we discussed the probabillity of having a nonlinear regression instead of a linear regression,therefore we may be able to improved using nonlinear regression technique as follows

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures



x = d2['Social support'].values
y = d2['Ladder score'].values

x= x.reshape(-1, 1)
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
##naming the labels
plt.xlabel('Social support')
plt.ylabel('happyness score')

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe502a48200b> in <module>()
#      14
#      15
# ---> 16 x = d2['Social support'].values
#      17 y = d2['Ladder score'].values
#      18
#
# NameError: name 'd2' is not defined

# %% [markdown]
# ###Plot B

# %%
x = d2['Healthy life expectancy']
y = d2['Social support']

x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')

plt.ylabel('Social support')
plt.xlabel('Healthy life expectancy')

plt.show()
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)

##positive correlation between health life expectancy and social support
# Out:
# The mean Squared for the above graph is  4.746121421820434

# %%
x = d2['Healthy life expectancy'].values
y = d2['Social support'].values

x= x.reshape(-1, 1)
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')

plt.ylabel('Social support')
plt.xlabel('Healthy life expectancy')

plt.show()
##using polinomail regression of degree 3 we notice a peak figure forming at around 75 years of age
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)
print(r2)
# Out:
# The mean Squared for the above graph is  0.13818849384495513
# -0.3030863738522156

# %% [markdown]
# ##Plot C

# %%
x = d1['DASS_depression'].values
y = d1['Age'].values

x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')

plt.xlabel('Social support')
plt.ylabel('happyness score')

plt.show()



#slight negative correlation

# %% [markdown]
# ##Plot D
# In this regression model we will try to plot the average stress and the average concern of covid 19 from our D3 dataset ,we have lowered the sample count in this plot so we can visualize the plot more clearly

# %%
y = d2['Logged GDP per capita'].values
x = d2['Ladder score'].values



x= x.reshape(-1, 1)
polynomial_features= PolynomialFeatures(degree=1)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')

plt.ylabel('Logged GDP per capita')
plt.xlabel('happyness score')

plt.show()
##using polinomail regression of degree 3 we notice a peak figure forming at around 75 years of age
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)
print(r2)
# Out:
# The mean Squared for the above graph is  1.4997863490570469
# -0.5681789350253474

# %%
y = d2['Logged GDP per capita'].values
x = d2['Ladder score'].values



x= x.reshape(-1, 1)
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')



plt.ylabel('Logged GDP per capita')
plt.xlabel('happyness score')


plt.show()
##using polinomail regression of degree 3 we notice a peak figure forming at around 75 years of age
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print('The mean Squared for the above graph is ',rmse)
print(r2)
# Out:
# The mean Squared for the above graph is  1.4992778888032443
# -0.5671158216036647

# %% [markdown]
# ##Plot E
# In this model, we will try to implement a regression model on the stress and age values from D1 Dataset to see the type of correlations we get

# %%
x = d1['DASS_stress']
y = d1['Age']
print(y.shape)


x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()
#negative correlation stress and age
# Out:
# (943,)

# %% [markdown]
# ### Results & Discussion
# In this part we are going to conclude with our results that we got from our research.
#
# In our hypothesis test:
# In the first hypothesis,we have found that "The majority of people will score 4 or more on the stress test" during this pandemic. This would be very reasonable as more and more people may feel more stressed during lockdowns caused by the pandemic environment.
#
# In the second hypothesis, we have found that "the majority of people will score 7 or more on the belief in their health system test". This could be explained by the massive collective panic from the pandemic and the change in people's lives which draws them closer to believing doctors more than anyone else during this pandemic.
#
# In the third hypothesis, we have found that "the majority of people will score 8 or more on their Trust in People test". This could also be explained by the sudden feeling of solidarity that the pandemic has created for the people of the globe as they are now facing a common threat which is the virus and its repercussions.
#
# In our machine learning models:
# We used both linear and nonlinear regression to find patterns in the data points we have collected and cleaned.
#
# In graph A, we used regression for social support and happiness scores to determine any relationship between the two scores.According to our model this is a clearly positive correlation between the two.therefore we can assume that the two are positively correlated meaning that both social support and happiness are strongly related in this pandemic. but we have digged deeper into it to find out that in fact. the correlation is not just linear but polynomial with degree = 2 .this would put happiness to grow quadratically in relation to social support during these pandemic
#
#
# In graph B, we have found that there exists a positive correlation between health life expectancy and social support during the pandemic.We then set out to create a nonlinear regression model to discover more about the data . Which gave us an interesting graph at degree = 2. According to the nonlinear regression graph,there should exist a plateau where the derivative of the graph should equal zero around the age of 75 . This could mean that until a certain age social support can be beneficial to increasing life expectancy.However life expectancy has many more factors other than social support that plays a role in it.
#
#
#
# In graph C, we have investigated the relationship between depression and age. the results showed us a negative correlation between age and depression in the following sample.this could be explained by the fact that teenager and young adults are more prone to depression in general.which conforms another research done by UCL ,https://www.ucl.ac.uk/news/2019/feb/teenagers-more-likely-suffer-depression-decade-ago#:~:text=Instead%2C%20 poor%20sleep%2C%20 obesity%20and,ill%2Dhealth%20must%20be%20changing. At the moment, the pandemic shows that it wasn't much different on the psychological health of young adults and teenagers than before the pandemic
#
#
#
#
# In graph D, we investigated the relationship between happyness scores and the logged GDP per capita to find any relationship.after building our model,we discovered that there is indeed a positive correlation between the two =,which explains that financial well being is still a high priority for people even during the pandemic.
#
#
# In graph E, we investigated the relationship between  stress and age. Surprisingly we have found a negative correlation using our regression model.
# This could tell us that old people are less likely to feel stressed than the younger generation . Again,the sudden lockdown and uncertainty in the world could drive more young adults and teenagers to be more stressed than their already established parents and adults in the same community.

# %% [markdown]
# ## Conclusion
# According to our research project, Doctors and Health professionals could use some of the eights in order to tackle the societal and mental side effects of this pandemic.
